# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", 16)

# %%
df = pd.read_csv("ticketsdata\data.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\tammi\AppData\Local\Temp\ipykernel_52016\248728353.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv("ticketsdata\data.csv")

# %%
df
# Out:
#                                                  subject  \
# 0                        Wesentlicher Sicherheitsvorfall
# 1                                     Account Disruption
# 2      Query About Smart Home System Integration Feat...
# 3                      Inquiry Regarding Invoice Details
# 4      Question About Marketing Agency Software Compa...
# ...                                                  ...
# 28582       Performance Problem with Data Analytics Tool
# 28583          Datensperrung in der Kundschaftsbetreuung
# 28584      Problem mit der Videokonferenz-Software heute
# 28585  Update Request for SaaS Platform Integration F...
# 28586          Inquiry About Project Management Features
#
#                                                     body  \
# 0      Sehr geehrtes Support-Team,\n\nich möchte eine...
# 1      Dear Customer Support Team,\n\nI am writing to...
# 2      Dear Customer Support Team,\n\nI hope this mes...
# ...

# %%
df.info()
df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28587 entries, 0 to 28586
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   subject   24749 non-null  str
#  1   body      28587 non-null  str
#  2   answer    28580 non-null  str
#  3   type      28587 non-null  str
#  4   queue     28587 non-null  str
#  5   priority  28587 non-null  str
#  6   language  28587 non-null  str
#  7   version   28587 non-null  int64
#  8   tag_1     28587 non-null  str
#  9   tag_2     28574 non-null  str
#  10  tag_3     28451 non-null  str
#  11  tag_4     25529 non-null  str
#  12  tag_5     14545 non-null  str
#  13  tag_6     5874 non-null   str
#  14  tag_7     2040 non-null   str
#  15  tag_8     565 non-null    str
# dtypes: int64(1), str(15)
# memory usage: 3.5 MB
# (28587, 16)

# %%
df.isna().sum()
# Out:
# subject      3838
# body            0
# answer          7
# type            0
# queue           0
# priority        0
# language        0
# version         0
# tag_1           0
# tag_2          13
# tag_3         136
# tag_4        3058
# tag_5       14042
# tag_6       22713
# tag_7       26547
# tag_8       28022
# dtype: int64

# %%
df.columns
# Out:
# Index(['subject', 'body', 'answer', 'type', 'queue', 'priority', 'language',
#        'version', 'tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6',
#        'tag_7', 'tag_8'],
#       dtype='str')

# %%
df.drop(columns=[
       'version', 'tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6',
       'tag_7', 'tag_8'],
       inplace=True)
df
# Out:
#                                                  subject  \
# 0                        Wesentlicher Sicherheitsvorfall
# 1                                     Account Disruption
# 2      Query About Smart Home System Integration Feat...
# 3                      Inquiry Regarding Invoice Details
# 4      Question About Marketing Agency Software Compa...
# ...                                                  ...
# 28582       Performance Problem with Data Analytics Tool
# 28583          Datensperrung in der Kundschaftsbetreuung
# 28584      Problem mit der Videokonferenz-Software heute
# 28585  Update Request for SaaS Platform Integration F...
# 28586          Inquiry About Project Management Features
#
#                                                     body  \
# 0      Sehr geehrtes Support-Team,\n\nich möchte eine...
# 1      Dear Customer Support Team,\n\nI am writing to...
# 2      Dear Customer Support Team,\n\nI hope this mes...
# ...

# %%
df = df.loc[df['language'] == 'en',:]
df
# Out:
#                                                  subject  \
# 1                                     Account Disruption
# 2      Query About Smart Home System Integration Feat...
# 3                      Inquiry Regarding Invoice Details
# 4      Question About Marketing Agency Software Compa...
# 5                                          Feature Query
# ...                                                  ...
# 28578                    Problem with Billing Adjustment
# 28580  Urgent: Incident Involving Data Breach in Medi...
# 28582       Performance Problem with Data Analytics Tool
# 28585  Update Request for SaaS Platform Integration F...
# 28586          Inquiry About Project Management Features
#
#                                                     body  \
# 1      Dear Customer Support Team,\n\nI am writing to...
# 2      Dear Customer Support Team,\n\nI hope this mes...
# 3      Dear Customer Support Team,\n\nI hope this mes...
# ...

# %%
df.isna().sum()
# Out:
# subject     2607
# body           0
# answer         3
# type           0
# queue          0
# priority       0
# language       0
# dtype: int64

# %%
df.dropna(inplace=True)
df.drop(columns=['answer','language'],inplace=True)

# %%
print(df.type.value_counts(),'\n')
print(df.queue.value_counts(),'\n')
print(df.priority.value_counts(),'\n')
# Out:
# type
# Incident    5531
# Request     3929
# Problem     2872
# Change      1397
# Name: count, dtype: int64
#
# queue
# Technical Support                  3971
# Product Support                    2606
# Customer Service                   2045
# IT Support                         1609
# Billing and Payments               1349
# Returns and Exchanges               686
# Service Outages and Maintenance     581
# Sales and Pre-Sales                 410
# Human Resources                     285
# General Inquiry                     187
# Name: count, dtype: int64
#
# priority
# medium    5593
# high      5304
# low       2832
# Name: count, dtype: int64

# %%
df
# Out:
#                                                  subject  \
# 1                                     Account Disruption
# 2      Query About Smart Home System Integration Feat...
# 3                      Inquiry Regarding Invoice Details
# 4      Question About Marketing Agency Software Compa...
# 5                                          Feature Query
# ...                                                  ...
# 28578                    Problem with Billing Adjustment
# 28580  Urgent: Incident Involving Data Breach in Medi...
# 28582       Performance Problem with Data Analytics Tool
# 28585  Update Request for SaaS Platform Integration F...
# 28586          Inquiry About Project Management Features
#
#                                                     body      type  \
# 1      Dear Customer Support Team,\n\nI am writing to...  Incident
# 2      Dear Customer Support Team,\n\nI hope this mes...   Request
# 3      Dear Customer Support Team,\n\nI hope this mes...   Request
# ...

# %%
#df.to_json('ticketsdata\clean.json')

# %%
df_clean = pd.read_json('ticketsdata\clean.json')
df_clean
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\tammi\AppData\Local\Temp\ipykernel_52016\798271381.py:1: SyntaxWarning: invalid escape sequence '\c'
#   df_clean = pd.read_json('ticketsdata\clean.json')
#                                                  subject  \
# 1                                     Account Disruption
# 2      Query About Smart Home System Integration Feat...
# 3                      Inquiry Regarding Invoice Details
# 4      Question About Marketing Agency Software Compa...
# 5                                          Feature Query
# ...                                                  ...
# 28578                    Problem with Billing Adjustment
# 28580  Urgent: Incident Involving Data Breach in Medi...
# 28582       Performance Problem with Data Analytics Tool
# 28585  Update Request for SaaS Platform Integration F...
# 28586          Inquiry About Project Management Features
#
# ...
