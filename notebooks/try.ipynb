# %%
import joblib
import joblib


model = joblib.load('ticket_classifier.joblib')
le = joblib.load('le.joblib')

# %%
def ask(text:str):
    return le.inverse_transform(model.predict([str(text)]))[0]

# %%
text = input("Enter ticket body")
print(ask(text))
# Out:
# Technical Support
